# %%
#output files paths
#PB_FILE_PATH = '/home/sunday/WorkSpace/Project/Jetson_Demo/FaceRecognitionEtESystem/face_recognition/models/mobilefacenet_model/MobileFaceNet_9925_9680.pb'
PB_FILE_PATH = '../face_recognition/models/mobilefacenet_model/MobileFaceNet_9925_9680.pb'
ONNX_FILE_PATH = '../face_recognition/models/mobilefacenet_model/MobileFaceNet.onnx'
ONNX_PATH = '../face_recognition/models/mobilefacenet_model/MobileFaceNet.onnx'
TRT_ENGINE_PATH = '../face_recognition/models/mobilefacenet_model/MobileFacenet_engine.plan'
#End user defined values

# %%
input_name = 'input'
output_node_names = 'embeddings'

# %%
# !python -m tf2onnx.convert --input {PB_FILE_PATH}  --inputs {input_name}:0[1,112,112,3] --outputs {output_node_names}:0 --output {ONNX_FILE_PATH}
# Out:
# 2023-10-07 23:41:52.291239: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-07 23:41:52.291273: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-07 23:41:52.291317: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-07 23:41:52.297782: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from onnx_to_trt import create_engine

# %%
create_engine(ONNX_PATH, TRT_ENGINE_PATH)
# Out:
# ONNX model laoded...
# Creating engine from this onnx file,  ../face_recognition/models/mobilefacenet_model/MobileFaceNet.onnx
# TRT engine created and saved at,  ../face_recognition/models/mobilefacenet_model/MobileFacenet_engine.plan
