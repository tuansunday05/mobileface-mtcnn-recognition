# %%
#output files paths
PB_FILE_PATH = '/home/sunday/WorkSpace/Project/Jetson_Demo/FaceRecognitionEtESystem/face_recognition/models/mobilefacenet_model/MobileFaceNet_9925_9680.pb'
ONNX_FILE_PATH = './mobilefacenet.onnx'
TRT_ENGINE_PATH = '/acenet_engine.plan'
#End user defined values

# %%
# !pwd
# Out:
# /home/sunday/WorkSpace/Project/Jetson_Demo/FaceRecognitionEtESystem/ConvertTensorRT

# %%
input_name = 'input:0'
output_node_names = 'embeddings:0'

# %%
# !python -m tf2onnx.convert --input '/home/sunday/WorkSpace/Project/Jetson_Demo/FaceRecognitionEtESystem/face_recognition/models/mobilefacenet_model/MobileFaceNet_9925_9680.pb' --inputs 'input:0' --outputs 'embeddings:0' --output '/home/sunday/WorkSpace/Project/Jetson_Demo/FaceRecognitionEtESystem/ConvertTensorRT/mobilefacenet.onnx'
# Out:
# /home/sunday/anaconda3/envs/jetson-sdk/lib/python3.7/runpy.py:125: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# WARNING:tensorflow:From /home/sunday/anaconda3/envs/jetson-sdk/lib/python3.7/site-packages/tf2onnx/verbose_logging.py:76: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2023-09-29 21:48:51,436 - WARNING - From /home/sunday/anaconda3/envs/jetson-sdk/lib/python3.7/site-packages/tf2onnx/verbose_logging.py:76: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# 2023-09-29 21:48:52,779 - INFO - Using tensorflow=1.15.0, onnx=1.14.1, tf2onnx=1.15.1/37820d
# 2023-09-29 21:48:52,779 - INFO - Using opset <onnx, 15>
# 2023-09-29 21:48:53,405 - WARNING - Cannot infer shape for phase_train: phase_train:0
# ...

# %%
# from onnx_to_trt import create_engine
